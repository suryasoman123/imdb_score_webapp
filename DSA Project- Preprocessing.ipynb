# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('movie_metadata.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %% [markdown]
#  The details for the dataset attributes:-
#
# 1.Color :- Movie is black or coloured
# 2.Director_name:- Name of the movie director
# 3.num_critic_for_reviews :- No of critics for the movie
# 4.duration:- movie duration in minutes
# 5.director_facebook_likes:-Number of likes for the Director on his Facebook Page
# 6.actor_3_facebook_likes:- No of likes for the actor 3 on his/her facebook Page
# 7.actor2_name:- name of the actor 2
# 8.actor_1_facebook_likes:- No of likes for the actor 1 on his/her facebook Page
# 9.gross:- Gross earnings of the movie in Dollars
# 10.genres:- Film categorization like ‘Animation’, ‘Comedy’, ‘Romance’, ‘Horror’, ‘Sci-Fi’, ‘Action’, ‘Family’
# 11.actor_1_name:- Name of the actor 1
# 12.movie_title:-Title of the movie
# 13.num_voted_users:-No of people who voted for the movie
# 14.cast_total_facebook_likes:- Total facebook like for the movie
# 15.actor_3_name:- Name of the actor 3
# 16.facenumber_in_poster:- No of actors who featured in the movie poster
# 17.plot_keywords:-Keywords describing the movie plots
# 18.movie_imdb_link:-Link of the movie link
# 19.num_user_for_reviews:- Number of users who gave a review
# 20.language:- Language of the movie
# 21.country:- Country where movie is produced
# 22.content_rating:- Content rating of the movie
# 23.budget:- Budget of the movie in Dollars
# 24.title_year:- The year in which the movie is released
# 25.actor_2_facebook_likes:- facebook likes for the actor 2
# 26.imdb_score:- IMDB score of the movie
# 27.aspect_ratio :- Aspect ratio the movie was made in
# 28.movie_facebook_likes:- Total no of facebook likes for the movie
#
#
# Categorical Columns
#
# Color,Director name, actor name,genres,movie_title,language,country,content_rating.
#
# Numerical Columns
#
# num_critic_for_reviews,duration,director_facebook_likes ,actor_3_facebook_likes,actor_1_facebook_likes ,gross,num_voted_users,cast_total_facebook_likes,facenumber_in_poster,num_user_for_reviews ,budget,title_year, actor_2_facebook_likes ,imdb_score,aspect_ratio,movie_facebook_likes

# %%
#Summary for the numerical columns in the dataset
df.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4993.0  1.401943e+02  1.216017e+02     1.00
# duration                   5028.0  1.072011e+02  2.519744e+01     7.00
# director_facebook_likes    4939.0  6.865092e+02  2.813329e+03     0.00
# actor_3_facebook_likes     5020.0  6.450098e+02  1.665042e+03     0.00
# actor_1_facebook_likes     5036.0  6.560047e+03  1.502076e+04     0.00
# gross                      4159.0  4.846841e+07  6.845299e+07   162.00
# num_voted_users            5043.0  8.366816e+04  1.384853e+05     5.00
# cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# facenumber_in_poster       5030.0  1.371173e+00  2.013576e+00     0.00
# num_user_for_reviews       5022.0  2.727708e+02  3.779829e+02     1.00
# budget                     4551.0  3.975262e+07  2.061149e+08   218.00
# title_year                 4935.0  2.002471e+03  1.247460e+01  1916.00
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# # EDA

# %%
#Plotting the Correlation between the numerical values of the Dataset
_, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap='coolwarm', annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
print(df['title_year'].value_counts().reset_index().sort_values(by='title_year', ascending=False).head(10))
plt.figure(figsize=(18,8))
sns.countplot(df['title_year'].sort_values(ascending=False))
plt.title('Movies released per year 1916-2016')
plt.xlabel('Year')
plt.ylabel('Movies Released')
plt.xticks(rotation=90)
plt.show()
# Out:
#     index  title_year
# 0  2009.0         260
# 1  2014.0         252
# 2  2006.0         239
# 3  2013.0         237
# 4  2010.0         230
# 5  2015.0         226
# 6  2011.0         225
# 7  2008.0         225
# 8  2012.0         221
# 9  2005.0         221

# %% [markdown]
# Highest number of movies were released in the year 2009 followed by 2014 and 2006.

# %%
#Plotting the range of IMDB scores of movies for every year
plt.figure(figsize=(20,8))
plt.title('IMDB score of movies over the years')
sns.barplot(x = df.title_year, y=df.imdb_score)
plt.xlabel('Year')
plt.ylabel('IMDB Score')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['genres'])
# Out:
# (array([1121., 1274.,  840.,  453.,  526.,  280.,  174.,  143.,  123.,
#          109.]),
#  array([  0. ,  91.3, 182.6, 273.9, 365.2, 456.5, 547.8, 639.1, 730.4,
#         821.7, 913. ]),
#  <BarContainer object of 10 artists>)

# %%
#Top 20 directors based on the IMDB scores
plt.figure(figsize=(10,8))
movie_df= df.sort_values(by ='imdb_score' , ascending=False)
movie_df_new=movie_df.head(20)
ax=sns.pointplot(movie_df_new['director_name'], movie_df_new['imdb_score'], hue=movie_df_new['movie_title'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
#Top 20 actors of movies based on the imdb scores of the movies 

plt.figure(figsize=(10,8))

movie_df= movie_df.sort_values(by ='imdb_score' , ascending=False)
movie_df_new=movie_df.head(20)
ax=sns.pointplot(movie_df_new['actor_1_name'], movie_df_new['imdb_score'], hue=movie_df_new['movie_title'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
#Top 10 movies based on imdb score
plt.figure(figsize=(8,8))
movie_df= movie_df.sort_values(by ='imdb_score' , ascending=False)
movie_df_new=movie_df.head(10)
ax=sns.barplot(movie_df_new['movie_title'], movie_df_new['imdb_score'], hue=movie_df_new['country'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Country of Top 20 movies based on imdb score

plt.figure(figsize=(10,8))

movie_df= movie_df.sort_values(by ='imdb_score' , ascending=False)
movie_df_new=movie_df.head(20)
ax=sns.pointplot(movie_df_new['country'], movie_df_new['imdb_score'], hue=movie_df_new['movie_title'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
#Making a Donot graph for the content_rating column with the values less than 50 grouped as others
df.loc[df['content_rating'].isin((df['content_rating'].value_counts()[df['content_rating'].value_counts() < 50]).index), 'content_rating'] = 'other'
x = df.content_rating.value_counts().index
y = df.content_rating.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(y, labels=x,autopct='%1.1f%%', pctdistance=0.85)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Content Rating')
plt.show()

sns.distplot(df.content_rating.value_counts())
plt.title('Distribution of content rating corrected')
plt.show()

# %%
bg = df[['movie_facebook_likes', 'gross', 'imdb_score', 'content_rating']]
bg = bg.dropna()
sns.pairplot(bg[['movie_facebook_likes','imdb_score', 'content_rating']], hue='content_rating')

# %% [markdown]
# The above plots show the Popularity of Movie on Facebook based on the Rating Assigned to them as well as the IMDB score for each movie.
# From the distribution of R rated movies we can observe that these movies are most produced movies, but at the same time the likes they have are very low. These movies have IMDB score between 5 to 10 with the values peaking and reaching at the top just after 5 and declining sharply after 6 or 6.5
# In the imdb_score vs Movie_facebook_likes, we can see that there are only few movies which have high IMDB score and are extremely popular on facebook as well.

# %%
#Movies having IMDB Rating above 7, 8 and 9
#Plotting the count of movies with reppect to their IMDB Score.

# %%
print('There are {} movies with IMDB score > 7.'.format(len(df[df['imdb_score'] > 7])))
print('There are {} movies with IMDB score > 8.'.format(len(df[df['imdb_score'] > 8])))
print('There are {} movies with IMDB score >= 9.'.format(len(df[df['imdb_score'] >= 9])))
# Out:
# There are 1594 movies with IMDB score > 7.
# There are 253 movies with IMDB score > 8.
# There are 9 movies with IMDB score >= 9.

# %%
plt.figure(figsize=(10,5))
plt.title('IMDB Score Count')
plt.xlabel('IMDB Score')
sns.histplot(data=df,x='imdb_score',color='maroon',binwidth=0.75)
plt.show()

# %%
top10 = df['cast_total_facebook_likes'].value_counts().reset_index().sort_values(by='cast_total_facebook_likes', ascending=False).head(10)
print(top10)
temp = []
for i in range(10):
    temp.append(df.movie_title.iloc[[top10.index[i]]].values)
movies = []
for i in range(10):
    movies.append(temp[i][0])
top10 = pd.DataFrame(zip(movies, top10.cast_total_facebook_likes), columns=['movies', 'likes'])
top10
# Out:
#     index  cast_total_facebook_likes
# 0       0                         33
# 1       5                          7
# 2    2020                          6
# 3       2                          6
# 4     673                          5
# 5      29                          5
# 6    1044                          5
# 26   2024                          4
# 21   2251                          4
# 22   2486                          4
#                                               movies  likes
# 0                                            Avatar      33
# 1          Pirates of the Caribbean: At World's End       7
# 2                                           Spectre       6
# 3                             The Dark Knight Rises       6
# 4  Star Wars: Episode VII - The Force Awakens    ...      5
# 5                                       John Carter       5
# 6                                      Spider-Man 3       5
# 7                                           Titanic       4
# ...

# %% [markdown]
# The above table shows top 10 movies ranked by cast popularity on facebook

# %%
plt.title('Top 10 movies based on Cast popularity')
sns.barplot(data=top10, x='movies', y='likes')
plt.xticks(rotation=90)
plt.ylabel('Facebook Likes')
plt.show()

# %%
#Top Grossing movies worldwide
Gr = pd.DataFrame(zip(df.movie_title, df.gross, df.budget), columns=['movies', 'gross', 'budget'])
Gr = Gr.set_index('gross')
Gr = Gr.sort_index(ascending=False)
Gr.head(10)
# Out:
#                                                  movies       budget
# gross
# 760505847.0                                     Avatar   237000000.0
# 658672302.0                                    Titanic   200000000.0
# 652177271.0                             Jurassic World   150000000.0
# 623279547.0                               The Avengers   220000000.0
# 623279547.0                               The Avengers   220000000.0
# 533316061.0                            The Dark Knight   185000000.0
# 474544677.0  Star Wars: Episode I - The Phantom Menace   115000000.0
# 460935665.0         Star Wars: Episode IV - A New Hope    11000000.0
# 458991599.0                    Avengers: Age of Ultron   250000000.0
# 448130642.0                      The Dark Knight Rises   250000000.0

# %% [markdown]
# Avatar was the highest Grossing movie so far

# %%
# Dropping some features

# %% [markdown]
# #columns "actor_1_facebook_likes", "actor_2_facebook_likes", "actor_3_facebook_likes" are redundant as the counts of the likes for those actors are already included in "cast_total_facebook_likes" </b> column.

# %% [markdown]
# So we can drop those 3 columns.
# Also the column "movie_imdb_link" </b> is not required for our EDA as it won't be making any difference

# %%
df = df.drop(columns=['actor_1_facebook_likes','actor_2_facebook_likes', 'actor_3_facebook_likes', 'movie_imdb_link'], axis=1)
print('Shape: ', df.shape)
# Out:
# Shape:  (5043, 24)

# %%
df['color'].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
#Removing the color section as most of the movies is colored

df['color'].value_counts()
df.drop('color',axis=1,inplace=True)
print('Shape: ', df.shape)
# Out:
# Shape:  (5043, 23)

# %%
#Checking for the columns present in the datset
df.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_2_name', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %%
#No of the missing values in the dataset

df.isna().sum()
# Out:
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_2_name                  13
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# We can remove the null values from the dataset where the count is less . so that we don't loose much data 
df.dropna(axis=0,subset=['director_name', 'num_critic_for_reviews','duration','director_facebook_likes','actor_2_name','actor_1_name','actor_3_name','facenumber_in_poster','num_user_for_reviews','language','country','plot_keywords'],inplace=True)

# %%
df.shape
# Out:
# (4737, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4737 entries, 0 to 5042
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   director_name              4737 non-null   object
#  1   num_critic_for_reviews     4737 non-null   float64
#  2   duration                   4737 non-null   float64
#  3   director_facebook_likes    4737 non-null   float64
#  4   actor_2_name               4737 non-null   object
#  5   gross                      4093 non-null   float64
#  6   genres                     4737 non-null   object
#  7   actor_1_name               4737 non-null   object
#  8   movie_title                4737 non-null   object
#  9   num_voted_users            4737 non-null   int64
#  10  cast_total_facebook_likes  4737 non-null   int64
#  11  actor_3_name               4737 non-null   object
#  12  facenumber_in_poster       4737 non-null   float64
# ...

# %% [markdown]
# #Handling Missing values in the dataset

# %%
#Replacing the content rating with Value R as it has highest frequency

df["content_rating"].fillna(df["content_rating"].mode().loc[0], inplace = True)

# %%
#Replacing the aspect_ratio with the median of the value as the graph is right skewed 

df["aspect_ratio"].fillna(df["aspect_ratio"].median(),inplace=True)

# %%
#We need to replace the value in budget with the median of the value
df["budget"].fillna(df["budget"].median(),inplace=True)

# %%
# We need to replace the value in gross with the median of the value 

df['gross'].fillna(df['gross'].median(),inplace=True)

# %%
# Recheck that all the null values are removed

df.isna().sum()
# Out:
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_2_name                 0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
#Outlier detection and handling

# %%
#Outlier Detection
#Finding outliers
graph=df.select_dtypes(include=['int64','float64','object'])
graph.boxplot(figsize=(20,15))
plt.show()

# %%
#Ploting all the scatter matrix pairs in a single plot
sns.pairplot(df)

# %%
plt.figure(figsize=(7,7))
plt.boxplot( df['budget'] );
plt.show()

# %%
npcolumn1=df[['gross']].to_numpy()
#print(npcolumn1)
fig1, ax1 = plt.subplots()
ax1.boxplot(npcolumn1)
plt.show()

# %%
npcolumn2=df[['budget']].to_numpy()
#print(npcolumn1)
fig2, ax2 = plt.subplots()
ax2.boxplot(npcolumn2)
plt.show()

# %%
sns.boxplot( y=df["duration"] );
plt.show()

# %%
sns.boxplot( y=df["movie_facebook_likes"] );
plt.show()

# %%
df["movie_facebook_likes"].mean()
# Out:
# 7835.310956301457

# %%
boxplot = df.boxplot(column=['gross', 'budget'], return_type='axes')
type(boxplot)
plt.show()

# %% [markdown]
# Removing the outlier in the column gross using capping method using 90th percentile.

# %%
print(df['gross'].quantile(0.10))
print(df['gross'].quantile(0.90))
# Out:
# 686801.8
# 115759963.60000004

# %%
df['gross'] = np.where(df['gross'] <382601.8, 382601.8,df['gross'])
df['gross'] = np.where(df['gross'] >125025163.2, 125025163.2,df['gross'])

# %%
sns.boxplot( y=df["gross"] );
plt.show()

# %% [markdown]
# #Handling outliers in the column gross
# Q1=np.percentile(df['gross'],25,interpolation='midpoint')
# Q2=np.percentile(df['gross'],50,interpolation='midpoint')
# Q3=np.percentile(df['gross'],75,interpolation='midpoint')
# IQR=Q3-Q1
# low_limit=Q1-1.5*IQR
# Up_limit=Q3+1.5*IQR
# outlier=[]
# for x in df['gross']:
#     if((x>Up_limit) or (x<low_limit)):
#        outlier.append(x)
# print('Number of outliers',len(outlier))

# %% [markdown]
# low_limit=Q1-1.5*IQR
# Up_limit=Q3+1.5*IQR
# df['gross']=np.where(df['gross']>Up_limit,Up_limit,np.where(df['gross']<low_limit,low_limit,df['gross']))

# %% [markdown]
# plt.boxplot(df['gross'])
# plt.title('gross')

# %%
#Handling outliers in the column budget

# %%
Q1=np.percentile(df['budget'],25,interpolation='midpoint')
Q2=np.percentile(df['budget'],50,interpolation='midpoint')
Q3=np.percentile(df['budget'],75,interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
Up_limit=Q3+1.5*IQR
outlier=[]
for x in df['budget']:
    if((x>Up_limit) or (x<low_limit)):
       outlier.append(x)
print('Number of outliers',len(outlier))
# Out:
# Number of outliers 431

# %%
df['budget']=np.where(df['budget']>Up_limit,Up_limit,np.where(df['gross']<low_limit,low_limit,df['budget']))

# %%
plt.boxplot(df['budget'])
plt.title('budget')
# Out:
# Text(0.5, 1.0, 'budget')

# %%
#Using florring and capping outliers in the both columns have been handled

# %%
plt.boxplot(df['title_year'])
plt.title('title_year')
# Out:
# Text(0.5, 1.0, 'title_year')

# %% [markdown]
# # Label Encoding

# %%
#All the categorical columns and the columns with text data are being Label Encodeded in this step.

# %%
#Label encoding the categorical columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_list=['director_name', 'actor_2_name',
        'genres', 'actor_1_name',
        'actor_3_name','movie_title',
        'plot_keywords',
        'language', 'country', 'content_rating',
       'title_year', 'aspect_ratio']
df[cat_list]=df[cat_list].apply(lambda x:le.fit_transform(x))

# %%
#Plotting the Correlation between the numerical values of the Dataset
_, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), linewidths=.6, cmap='coolwarm', annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# So from the corelation heatmap we can select the features num_critic_for_review,duration ,director_facebook_likes,gross ,genres,num_voted_users,cast_total_facebook_likes,facenumber_in_poster,num_user_for_reviews,language,title_year,imdb_score, movie_facebook_likes rest can be dropped.

# %%
df.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_2_name', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %%
drop_list_cor = ['director_name','actor_2_name','actor_1_name', 'movie_title','actor_3_name','plot_keywords','country','content_rating', 'budget','aspect_ratio',]
df1 = df.drop(drop_list_cor,axis = 1 )        # do not modify df, we will use it later 
df1.head(2)
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes        gross  \
# 0                   723.0     178.0                      0.0  125025163.2
# 1                   302.0     169.0                    563.0  125025163.2
#
#    genres  num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0     101           886204                       4834                   0.0
# 1      95           471220                      48350                   0.0
#
#    num_user_for_reviews  language  title_year  imdb_score  \
# 0                3054.0        10          80         7.9
# 1                1238.0        10          78         7.1
#
#    movie_facebook_likes
# 0                 33000
# 1                     0

# %%
#correlation map
f,ax = plt.subplots(figsize=(14, 14))
sns.heatmap(df1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  • num voted users (numeric - ratio): Number of users that have voted the movie
#  • num critic for reviews (numeric - ratio): Number of critics that have written a review
#  • num user for reviews (numeric - ratio): Number of users that have written a review

# %% [markdown]
# # Separating the dataset to target  and independent features

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df1.drop(['imdb_score'],axis=1)
y = df1['imdb_score']

# %% [markdown]
# # Splitting the data into training data & Testing data¶

# %%
# spliting the data into trainning and test dateset
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# # Feature scaling

# %%
# feature scaling using StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3315, 12)
# (1422, 12)
# (3315,)
# (1422,)

# %%
#df1['imdb_score'].value_counts(normalize=True)

# %% [markdown]
# # Model Training

# %%
#Linear Regressor
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
print(y_test)
# Out:
# 2377    6.5
# 362     7.5
# 1432    6.6
# 1758    7.5
# 4092    6.6
#        ...
# 4608    6.8
# 110     6.3
# 3563    7.2
# 4257    7.6
# 59      6.2
# Name: imdb_score, Length: 1422, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))
# Out:
# MSE is: 0.7590277702060151

# %%
from sklearn.metrics import r2_score as r2
print(r2(y_test,predictions))
# Out:
# 0.37312870874281046

# %%
from sklearn.metrics import f1_score,accuracy_score,precision_score,confusion_matrix

# %%
#Visualization of test and prediction data
plt.figure(figsize=(5,5))
plt.scatter(y_test,predictions)

# %%
df1.head(2)
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes        gross  \
# 0                   723.0     178.0                      0.0  125025163.2
# 1                   302.0     169.0                    563.0  125025163.2
#
#    genres  num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0     101           886204                       4834                   0.0
# 1      95           471220                      48350                   0.0
#
#    num_user_for_reviews  language  title_year  imdb_score  \
# 0                3054.0        10          80         7.9
# 1                1238.0        10          78         7.1
#
#    movie_facebook_likes
# 0                 33000
# 1                     0

# %%
df1.shape
# Out:
# (4737, 13)

# %%
df1.drop_duplicates()
# Out:
#       num_critic_for_reviews  duration  director_facebook_likes        gross  \
# 0                      723.0     178.0                      0.0  125025163.2
# 1                      302.0     169.0                    563.0  125025163.2
# 2                      602.0     148.0                      0.0  125025163.2
# 3                      813.0     164.0                  22000.0  125025163.2
# 5                      462.0     132.0                    475.0   73058679.0
# ...                      ...       ...                      ...          ...
# 5034                    35.0      80.0                      0.0     382601.8
# 5035                    56.0      81.0                      0.0    2040920.0
# 5037                    14.0      95.0                      0.0     382601.8
# 5038                     1.0      87.0                      2.0   26005908.0
# 5042                    43.0      90.0                     16.0     382601.8
#
# ...

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df1.drop(['imdb_score'],axis=1)
y = df1['imdb_score']

# %%
# spliting the data into trainning and test dateset
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
#Linear Regressor
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))
# Out:
# MSE is: 0.7571079527119422

# %%
from sklearn.metrics import r2_score as r2
print(r2(y_test,predictions))
# Out:
# 0.3747142613651617

# %% [markdown]
# Here we have done linear regression with dropping duplicates and not scalling the data . Here also mse is 75.6

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators = 500)
rf_regressor.fit(X_train, y_train)
rf_pred = rf_regressor.predict(X_test)

# %%
mean_squared_error(rf_pred, y_test)
# Out:
# 0.5901205094514759

# %%
print(r2(y_test,rf_pred))
# Out:
# 0.5126270470225469

# %% [markdown]
# Here mse is reduced to 58.7 (no scaling, dropped the duplicates, 13 columns)

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

## training the model

ridgeReg = Ridge(alpha=0.05, normalize=True)

ridgeReg.fit(X_train,y_train)

rr_pred = ridgeReg.predict(X_test)

#calculating mse
print('MSE is:',mean_squared_error(rr_pred, y_test))
print('r2=:',r2(y_test,rr_pred))

# %% [markdown]
# # Lasso regression

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.3, normalize=True)

lassoReg.fit(X_train,y_train)

lasso_pred = lassoReg.predict(X_test)

# calculating mse
print('MSE is:',mean_squared_error(lasso_pred, y_test))
print('r2=:',r2(y_test,lasso_pred))

# %% [markdown]
# # Gradient Boosting with Hyper Parameter Tuning

# %%
from sklearn import ensemble
n_trees=200
gradientboost = ensemble.GradientBoostingRegressor(loss='ls',learning_rate=0.03,n_estimators=n_trees,max_depth=4)
gradientboost.fit(X_train,y_train)

# %%
y_pred_gb=gradientboost.predict(X_test)
error=gradientboost.loss_(y_test,y_pred_gb) ##Loss function== Mean square error
print("MSE:%.3f" % error)

# %% [markdown]
# # Cat Boost Regressor

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df1.drop(['imdb_score'],axis=1)
y = df1['imdb_score']

# %%
# spliting the data into trainning and test dateset
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# !pip3 install catboost

# %%
import catboost as cb
# split the dataset into dependent(X) and Independent(Y) datasets
X=df1.drop(['imdb_score'],axis=1)
y = df1['imdb_score']
# spliting the data into trainning and test dateset
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

train_dataset = cb.Pool(X_train, y_train) 
test_dataset = cb.Pool(X_test, y_test)

# %%
model = cb.CatBoostRegressor(loss_function='RMSE')
model.fit(X_train, y_train)

# %%
pred = model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, pred)))

#r2 = r2_score(y_test, pred)
#print(“Testing performance”)
print('RMSE: {:.2f}'.format(rmse))
print('r2:',r2(y_test,pred))
#print('R2: {:.2f}'.format(r2))

# %% [markdown]
# # Now we are using min max scaler for scalling and see how th model behaves

# %%
drop_list_cor = ['director_name','actor_2_name','actor_1_name', 'movie_title','actor_3_name','plot_keywords','country','content_rating', 'budget','aspect_ratio',]
df2 = df.drop(drop_list_cor,axis = 1 )        # do not modify df, we will use it later 
df2.head(2)

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df2.drop(['imdb_score'],axis=1)
y = df2['imdb_score']

# %%
# spliting the data into trainning and test dateset
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
# define min max scaler
scaler = MinMaxScaler()
# transform data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
#Linear Regressor
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train_scaled,y_train)
predictions=model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))
from sklearn.metrics import r2_score as r2
print(r2(y_test,predictions))

# %% [markdown]
# So scaling does affect the model training.

# %% [markdown]
# # Support Vector Regression

# %%
df2.head()

# %%
df3=df2.copy()

# %%
df3.head()

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df3.drop(['imdb_score'],axis=1)
y = df3['imdb_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# feature scaling using StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf', gamma=0.1)
svr_lin = SVR(kernel='linear', gamma='auto')
svr_poly = SVR(kernel='poly', gamma='auto', degree=3)

# %%
svr_rbf.fit(X_train, y_train)
y_pred_svm_rbf = svr_rbf.predict(X_test)

# %%
y_pred_svm_rbf

# %%
mean_squared_error(y_pred_svm_rbf, y_test)

# %% [markdown]
# So MSE has reduced to 72.25 which is better than linear regression

# %%
plt.figure(figsize=(5,5))
plt.scatter(y_test,y_pred_svm_rbf)

# %%
svr_lin.fit(X_train, y_train)
y_pred_svm_lin = svr_lin.predict(X_test)

# %%
y_pred_svm_lin

# %%
mean_squared_error(y_pred_svm_lin, y_test)

# %% [markdown]
# MSE is the highest among 3

# %%
svr_poly = SVR(kernel='poly', gamma='auto', degree=3)
svr_poly.fit(X_train, y_train)
y_pred_svm_poly = svr_poly.predict(X_test)

# %%
y_pred_svm_poly

# %%
mean_squared_error(y_pred_svm_poly, y_test)

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators = 500)
rf_regressor.fit(X_train, y_train)
rf_pred = rf_regressor.predict(X_test)

# %%
mean_squared_error(rf_pred, y_test)

# %% [markdown]
# Again MSE has reduced to 62.6

# %% [markdown]
#  Now again checking with vif value and train the model

# %%
#Plotting the Correlation between the numerical values of the Dataset
_, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), linewidths=.6, cmap='coolwarm',fmt='.2f',annot=True, ax=ax)

# %% [markdown]
# Lets find out the VIF of all the features and then we can drop those accordingly.

# %%
df4=df.copy()
df4.head(2)

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df4.drop(['imdb_score'],axis=1)
y = df4['imdb_score']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)

# %% [markdown]
# Lets drop the features which are greater than 5 .

# %%
df_drop_list2=['num_critic_for_reviews','duration','genres','language','country','content_rating','title_year','aspect_ratio']
df4=df4.drop(df_drop_list2,axis=1)
df4.head()

# %%
df4.shape

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df4.drop(['imdb_score'],axis=1)
y = df4['imdb_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# feature scaling using StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %%
#Linear Regressor
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))

# %%
from sklearn.metrics import r2_score as r2
print(r2(y_test,predictions))

# %%
#Visualization of test and prediction data
plt.figure(figsize=(5,5))
plt.scatter(y_test,predictions)

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators = 500)
rf_regressor.fit(X_train, y_train)
rf_pred = rf_regressor.predict(X_test)

# %%
mean_squared_error(rf_pred, y_test)

# %%
df4.drop_duplicates()

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
X=df4.drop(['imdb_score'],axis=1)
y = df4['imdb_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
#Linear Regressor
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))

# %%
from sklearn.metrics import r2_score as r2
print(r2(y_test,predictions))

# %%
predictions=model.predict(X_test)
